# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import scipy
# %matplotlib inline

plt.style.use('bmh')

# %%
# load the dataset

df = pd.read_csv('./polls/president_polls.csv', low_memory=False)
df.head()
# Out:
#    question_id  poll_id  cycle         state  pollster_id  \
# 0       136283    72621   2020          Iowa          383
# 1       136283    72621   2020          Iowa          383
# 2       136322    72647   2020  Pennsylvania          461
# 3       136322    72647   2020  Pennsylvania          461
# 4       136322    72647   2020  Pennsylvania          461
#
#                               pollster sponsor_ids sponsors  \
# 0                Public Policy Polling         NaN      NaN
# 1                Public Policy Polling         NaN      NaN
# 2  Susquehanna Polling & Research Inc.         NaN      NaN
# 3  Susquehanna Polling & Research Inc.         NaN      NaN
# 4  Susquehanna Polling & Research Inc.         NaN      NaN
#
#                           display_name  pollster_rating_id  ...  \
# 0                Public Policy Polling               263.0  ...
# 1                Public Policy Polling               263.0  ...
# 2  Susquehanna Polling & Research Inc.               326.0  ...
# 3  Susquehanna Polling & Research Inc.               326.0  ...
# 4  Susquehanna Polling & Research Inc.               326.0  ...
#
#       created_at notes                                                url  \
# 0  11/2/20 09:02   NaN  https://www.publicpolicypolling.com/wp-content...
# 1  11/2/20 09:02   NaN  https://www.publicpolicypolling.com/wp-content...
# 2  11/2/20 12:49   NaN  https://www.realclearpolitics.com/docs/2020/Su...
# 3  11/2/20 12:49   NaN  https://www.realclearpolitics.com/docs/2020/Su...
# 4  11/2/20 12:49   NaN  https://www.realclearpolitics.com/docs/2020/Su...
#
#      stage race_id     answer candidate_id       candidate_name  \
# 0  general    6223      Biden        13256  Joseph R. Biden Jr.
# 1  general    6223      Trump        13254         Donald Trump
# 2  general    6249      Biden        13256  Joseph R. Biden Jr.
# 3  general    6249      Trump        13254         Donald Trump
# 4  general    6249  Jorgensen        14611         Jo Jorgensen
#
#    candidate_party   pct
# 0              DEM  49.0
# 1              REP  48.0
# 2              DEM  48.4
# 3              REP  49.2
# 4              LIB   1.4
#
# [5 rows x 38 columns]

# %%
## Data cleaning and processing 

# Remove rows where the prediction is not about Biden or Trump
df = df[(df.answer == "Trump") | (df.answer == "Biden")]

# Convert date string to date time in Pandas
df.end_date = pd.to_datetime(df.end_date, infer_datetime_format = True)

# Use pd datetime to convert end date of polls into yearmonth format for monthly predictions
df['yearmonth'] = df['end_date'].dt.year.astype(str) + '-' + df['end_date'].dt.month.astype(str)

# Nan in state signifies the presidential elections
# treat these as a separate election with state = 'pres'
df['state'] = df['state'].fillna('pres')

# %%
# Group DF by the columns of interest
df.sort_values(by = 'yearmonth')
grouped_df = df.groupby(['pollster', 'state', 'yearmonth', 'answer']).tail(1)
grouped_df.head()
# Out:
#    question_id  poll_id  cycle         state  pollster_id  \
# 0       136283    72621   2020          Iowa          383
# 1       136283    72621   2020          Iowa          383
# 2       136322    72647   2020  Pennsylvania          461
# 3       136322    72647   2020  Pennsylvania          461
# 5       136491    72722   2020       Florida          235
#
#                               pollster sponsor_ids       sponsors  \
# 0                Public Policy Polling         NaN            NaN
# 1                Public Policy Polling         NaN            NaN
# 2  Susquehanna Polling & Research Inc.         NaN            NaN
# 3  Susquehanna Polling & Research Inc.         NaN            NaN
# 5       Opinion Savvy/InsiderAdvantage         364  FOX35 Orlando
#
#                           display_name  pollster_rating_id  ... notes  \
# 0                Public Policy Polling               263.0  ...   NaN
# 1                Public Policy Polling               263.0  ...   NaN
# 2  Susquehanna Polling & Research Inc.               326.0  ...   NaN
# 3  Susquehanna Polling & Research Inc.               326.0  ...   NaN
# 5                     InsiderAdvantage               243.0  ...   NaN
#
#                                                  url    stage race_id answer  \
# 0  https://www.publicpolicypolling.com/wp-content...  general    6223  Biden
# 1  https://www.publicpolicypolling.com/wp-content...  general    6223  Trump
# 2  https://www.realclearpolitics.com/docs/2020/Su...  general    6249  Biden
# 3  https://www.realclearpolitics.com/docs/2020/Su...  general    6249  Trump
# 5  https://www.realclearpolitics.com/docs/2020/Fo...  general    6220  Biden
#
#   candidate_id       candidate_name  candidate_party   pct yearmonth
# 0        13256  Joseph R. Biden Jr.              DEM  49.0   2020-11
# 1        13254         Donald Trump              REP  48.0   2020-11
# 2        13256  Joseph R. Biden Jr.              DEM  48.4   2020-11
# 3        13254         Donald Trump              REP  49.2   2020-11
# 5        13256  Joseph R. Biden Jr.              DEM  47.0   2020-11
#
# [5 rows x 39 columns]

# %%
# Create 'bidenAdvantage' column to store the difference between Biden and Trump's pct probability
# of winning according to the poll

biden_df = grouped_df.loc[grouped_df['answer'] == 'Biden']
trump_df = grouped_df.loc[grouped_df['answer'] == 'Trump']
merged_df = pd.merge(biden_df, trump_df, on = ['pollster', 'state', 'yearmonth', 'fte_grade'], how = 'inner', 
                     suffixes = ['Biden', 'Trump'])
merged_df['bidenAdvantage'] = merged_df['pctBiden'] - merged_df['pctTrump']

# Create the final dataframe that stores the 'bidenAdvantage' variable for each pollster, state, yearmonth
# Note that Maine and Nebraska are stored as 3 separate states -- e.g. Maine, Maine CD-1, Maine CD-2
# This is due to the electoral college rules in these states

scoreMatrix = merged_df[['pollster', 'fte_grade', 'state', 'yearmonth', 'bidenAdvantage']].sort_values(
    by = ['pollster', 'state', 'yearmonth'], ascending = False)

# %%
scoreMatrix
# Out:
#                                      pollster fte_grade           state  \
# 308                              co/efficient       C/D         Vermont
# 797                              co/efficient       C/D          Kansas
# 309                              co/efficient       C/D          Kansas
# 1299  brilliant corners Research & Strategies       NaN  South Carolina
# 699            Zogby Interactive/JZ Analytics        C+            pres
# 1053           Zogby Interactive/JZ Analytics        C+            pres
# 1269           Zogby Interactive/JZ Analytics        C+            pres
# 1512           Zogby Interactive/JZ Analytics        C+            pres
# 1707           Zogby Interactive/JZ Analytics        C+            pres
# 1822           Zogby Interactive/JZ Analytics        C+            pres
# 1844           Zogby Interactive/JZ Analytics        C+            pres
# 1956           Zogby Interactive/JZ Analytics        C+            pres
# 1985           Zogby Interactive/JZ Analytics        C+            pres
# 2043           Zogby Interactive/JZ Analytics        C+            pres
# 1879           Zogby Interactive/JZ Analytics        C+            pres
# 1942           Zogby Interactive/JZ Analytics        C+            pres
# 2054           Zogby Interactive/JZ Analytics        C+       Wisconsin
# 1996           Zogby Interactive/JZ Analytics        C+      Washington
# 1272           Zogby Interactive/JZ Analytics        C+    Pennsylvania
# 1271           Zogby Interactive/JZ Analytics        C+            Ohio
# 1273           Zogby Interactive/JZ Analytics        C+  North Carolina
# 1906           Zogby Interactive/JZ Analytics        C+         Georgia
# 1270           Zogby Interactive/JZ Analytics        C+         Florida
# 1986           Zogby Interactive/JZ Analytics        C+          Alaska
# 356                                  Zia Poll       C/D        Michigan
# 1240            YouGov Blue/Data for Progress       NaN            pres
# 942                                    YouGov         B            pres
# 1137                                   YouGov         B            pres
# 1362                                   YouGov         B            pres
# 1521                                   YouGov         B            pres
# ...                                       ...       ...             ...
# 960                              ALG Research       B/C    Pennsylvania
# 959                              ALG Research       B/C            Ohio
# 696                              ALG Research       B/C  North Carolina
# 764                              ALG Research       B/C          Nevada
# 1623                             ALG Research       B/C          Nevada
# 742                              ALG Research       B/C        Michigan
# 1094                             ALG Research       B/C       Louisiana
# 729              ABC News/The Washington Post        A+            pres
# 1083             ABC News/The Washington Post        A+            pres
# 1317             ABC News/The Washington Post        A+            pres
# 1533             ABC News/The Washington Post        A+            pres
# 1709             ABC News/The Washington Post        A+            pres
# 1806             ABC News/The Washington Post        A+            pres
# 499              ABC News/The Washington Post        A+            pres
# 1833             ABC News/The Washington Post        A+            pres
# 1973             ABC News/The Washington Post        A+            pres
# 2013             ABC News/The Washington Post        A+            pres
# 1907             ABC News/The Washington Post        A+            pres
# 841              ABC News/The Washington Post        A+       Wisconsin
# 270              ABC News/The Washington Post        A+       Wisconsin
# 350              ABC News/The Washington Post        A+        Virginia
# 714              ABC News/The Washington Post        A+    Pennsylvania
# 196              ABC News/The Washington Post        A+    Pennsylvania
# 359              ABC News/The Washington Post        A+  North Carolina
# 840              ABC News/The Washington Post        A+       Minnesota
# 269              ABC News/The Washington Post        A+        Michigan
# 774              ABC News/The Washington Post        A+         Florida
# 195              ABC News/The Washington Post        A+         Florida
# 773              ABC News/The Washington Post        A+         Arizona
# 2008                             1892 Polling       B/C    North Dakota
#
#      yearmonth  bidenAdvantage
# 308    2020-10            30.0
# 797     2020-9           -12.0
# 309    2020-10           -17.0
# 1299    2020-7            -7.0
# 699     2020-9             2.1
# 1053    2020-8             3.0
# 1269    2020-7             4.0
# 1512    2020-6             0.0
# 1707    2020-3             1.0
# 1822    2020-2             0.0
# 1844    2020-1             3.0
# 1956    2019-9             3.0
# 1985    2019-8             0.0
# 2043    2019-5             8.0
# 1879   2019-12             1.0
# 1942   2019-10            -4.0
# 2054    2019-4             9.0
# 1996    2019-8            19.8
# 1272    2020-7             1.0
# 1271    2020-7             2.0
# 1273    2020-7             4.0
# 1906   2019-10             2.0
# 1270    2020-7             0.0
# 1986    2019-8            -5.0
# 356    2020-10            -4.0
# 1240    2020-7             6.0
# 942     2020-9            11.0
# 1137    2020-8             9.0
# 1362    2020-7             5.0
# 1521    2020-6             4.0
# ...        ...             ...
# 960     2020-9             6.0
# 959     2020-9             2.0
# 696     2020-9             3.0
# 764     2020-9             4.0
# 1623    2020-4             4.0
# 742     2020-9             8.0
# 1094    2020-8            -7.0
# 729     2020-9            10.0
# 1083    2020-8            10.0
# 1317    2020-7            10.0
# 1533    2020-5            10.0
# 1709    2020-3             2.0
# 1806    2020-2             6.0
# 499    2020-10            11.0
# 1833    2020-1             3.0
# 1973    2019-9            12.0
# 2013    2019-7             6.0
# 1907   2019-10            15.0
# 841     2020-9             6.0
# 270    2020-10            17.0
# 350    2020-10            11.0
# 714     2020-9            10.0
# 196    2020-10             7.0
# 359    2020-10             2.0
# 840     2020-9            16.0
# 269    2020-10             7.0
# 774     2020-9            -4.0
# 195    2020-10            -2.0
# 773     2020-9            -1.0
# 2008    2019-7           -26.0
#
# [2091 rows x 5 columns]

# %%
#CNN elections results at 10 AM ET 11/18/2020
results_df = pd.read_csv('./results.csv')
state_result_dict = {}
for index, row in results_df.iterrows():
    state_result_dict[row["State"]]= row["bidenAdvantage"]
results_df.head()
# Out:
#             State  bidenAdvantage
# 0         Vermont       35.412652
# 1  South Carolina      -11.680206
# 2         Indiana      -16.067912
# 3        Kentucky      -25.951940
# 4         Georgia        0.280950

# %%
fte_grades = ['A+','A','A-','B+', 'B','B-','C+','C','C-','D-']

# remove rows where there is no pollster grade
scoreMatrix = scoreMatrix.loc[np.isin(scoreMatrix['fte_grade'], fte_grades)]

# select the latest poll from for each pollster and state
latest_polls = scoreMatrix.groupby(['pollster', 'state']).first()

latest_polls.head()
# Out:
#                                             fte_grade yearmonth  \
# pollster                     state
# ABC News/The Washington Post Arizona               A+    2020-9
#                              Florida               A+    2020-9
#                              Michigan              A+   2020-10
#                              Minnesota             A+    2020-9
#                              North Carolina        A+   2020-10
#
#                                              bidenAdvantage
# pollster                     state
# ABC News/The Washington Post Arizona                   -1.0
#                              Florida                   -4.0
#                              Michigan                   7.0
#                              Minnesota                 16.0
#                              North Carolina             2.0

# %%
aggregated_grade_df = []
for fte_grade in fte_grades:
    count = 0
    totalMSE = 0
    for index, row in latest_polls.iterrows():
        if row[0] == fte_grade:
            count += 1
            totalMSE += (row.bidenAdvantage - state_result_dict[index[1]]) ** 2
    
    aggregated_grade_df.append([fte_grade, count, totalMSE/count])
aggregated_grade_df = pd.DataFrame(aggregated_grade_df, columns=['fte_grade','pollster_count', 'mean_MSE'])
aggregated_grade_df
# Out:
#   fte_grade  pollster_count   mean_MSE
# 0        A+              52  34.406388
# 1         A              23  31.084558
# 2        A-              39  44.351626
# 3        B+              31  60.185119
# 4         B              50  33.968631
# 5        B-              43  27.016327
# 6        C+              20  26.909133
# 7         C              30  29.909098
# 8        C-              32  22.173066
# 9        D-              80  58.870296

# %%
scipy.stats.pearsonr(np.array(range(10)), aggregated_grade_df['mean_MSE'])
# Out:
# (-0.02924341785535903, 0.9360847010611283)

# %%
fig=plt.figure(figsize=(12,8), dpi= 100, facecolor='w', edgecolor='k')

fig, ax = plt.subplots()
ax.plot(aggregated_grade_df.fte_grade, aggregated_grade_df.mean_MSE)

plt.xlabel("FiveThirtyEight Pollster Grade")
plt.ylabel("Mean MSE of pollsters")


x = np.array(range(10))
slope, intercept, r, p, std_err = scipy.stats.linregress(x, aggregated_grade_df.mean_MSE)


def myfunc(x):
    return slope * x + intercept
mymodel = list(map(myfunc, x))
ax.plot(aggregated_grade_df.fte_grade, mymodel)
